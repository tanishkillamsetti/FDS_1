# %% [markdown]
# <a href="https://colab.research.google.com/github/tanishkillamsetti/FDS_1/blob/main/iris_central.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pdb
df = pd.read_csv("iris.csv")
print("Iris Dataset:")
print(df)
# Out:
# Iris Dataset:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#rows and columns
print("\nFirst 5 rows:")
print(df.head())
print("\nColumn Names:")
print(df.columns)
# Out:
# First 5 rows:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
# Column Names:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
numeric_columns = df.select_dtypes(include='number').columns
print("\nNumerical Columns:")
print(numeric_columns)
# Out:
# Numerical Columns:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='object')

# %%
# Mean
print("\n----- MEAN -----")
print(df[numeric_columns].mean())
# Out:
# ----- MEAN -----
# sepal_length    5.843333
# sepal_width     3.054000
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %%
#Median
print("\n----- MEDIAN -----")
print(df[numeric_columns].median())
# Out:
# ----- MEDIAN -----
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
#Mode
print("\n----- MODE -----")
print(df[numeric_columns].mode())
# Out:
# ----- MODE -----
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.0          3.0           1.5          0.2

# %%
# Minimum
print("\n----- MINIMUM -----")
print(df[numeric_columns].min())
#Maximum
print("\n----- MAXIMUM -----")
print(df[numeric_columns].max())
# Out:
# ----- MINIMUM -----
# sepal_length    4.3
# sepal_width     2.0
# petal_length    1.0
# petal_width     0.1
# dtype: float64
#
# ----- MAXIMUM -----
# sepal_length    7.9
# sepal_width     4.4
# petal_length    6.9
# petal_width     2.5
# dtype: float64
